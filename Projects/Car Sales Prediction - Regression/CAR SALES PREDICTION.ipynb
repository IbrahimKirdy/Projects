# %% [markdown]
# <h1 style="color: DeepSkyBlue; text-align: center;">Car Sales Predictions </h1>

# %% [markdown]
# <h5 style="color: DeepSkyBlue; text-align: left;">Prepared By : Ibrahim Kerdi</h5>

# %% [markdown]
# ## Importing the libraries

# %% [markdown]
# In this notebook, we will be using the following libraries.

# %%
# Data Wrangling 

import numpy as np
import pandas as pd
import missingno
from collections import Counter
from collections import OrderedDict

# Data Visualization

import matplotlib.pyplot as plt
import seaborn as sns

# Data Preprocessing

import statsmodels.api as sm
from scipy import stats

# Modelling 

from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error, r2_score , mean_absolute_error , mean_absolute_percentage_error
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
import xgboost as xg

### Tabulating the results

from tabulate import tabulate

### Remove unnecessary warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the data

# %% [markdown]
# In this section, I will fetch the dataset that is available in the Kaggle's project description in the Data section.
#
# The training set should be used to build your machine learning models. For the training set, we provide the outcome (also known as the “ground truth”) for each Car model. Your model will be based on “features” like Manufacturer, Model, Vehicle Type, Horsepower etc. You can also use feature engineering to create new features.
#
# The test set should be used to see how well your model performs on unseen data. For the test set, we do not provide the ground truth. It is your job to predict these outcomes. For each car, our task is to predict the sales price of the car.

# %%
dataset = pd.read_csv('./data/Car_sales.csv')

# %%
dataset.head(10)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
# 6         Audi       A8               1.380               39.000    Passenger
# 7          BMW     323i              19.747                  NaN    Passenger
# 8          BMW     328i               9.231               28.675    Passenger
# 9          BMW     528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
# 6               62.00          4.2       310.0      113.0   74.0   198.2
# 7               26.99          2.5       170.0      107.3   68.4   176.0
# 8               33.40          2.8       193.0      107.3   68.5   176.0
# 9               38.90          2.8       193.0      111.4   70.9   188.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
# 5        3.561           18.5             22.0      8/9/2011
# 6        3.902           23.7             21.0     2/27/2012
# 7        3.179           16.6             26.0     6/28/2011
# 8        3.197           16.6             24.0     1/29/2012
# 9        3.472           18.5             25.0      4/4/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# 3          91.389779
# 4          62.777639
# 5          84.565105
# 6         134.656858
# 7          71.191207
# 8          81.877069
# 9          83.998724

# %%
# Shape of the dataset

dataset.shape
# Out:
# (157, 16)

# %% [markdown]
# The dataset consists of 16 columns and 157 rows.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.
#
# Here, we will perform EDA on the categorical columns of the dataset - Manufacturer, Vehicle_type and the numerical columns of the dataset - Sales_in_thousands, __year_resale_value, Price_in_thousands, Engine_size, Horsepower, Wheelbase, Width, Length, Curb_weight, Fuel_capacity, Fuel_efficiency, Power_perf_factor.

# %% [markdown]
# ### Datatypes, Missing Data, and Summary Statistics

# %%
# Looking at the datatypes of the dataset

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
#  15  Power_perf_factor    155 non-null    float64
# dtypes: float64(12), object(4)
# memory usage: 19.8+ KB

# %% [markdown]
# Manufacturer, Model, Vehicle_type are categorical. Hence, we modify the datatype of these columns to category.

# %%
# Modifying the datatypes of the columns to category
dataset.Manufacturer = dataset.Manufacturer.astype('category')
dataset.Model = dataset.Model.astype('category')
dataset.Vehicle_type = dataset.Vehicle_type.astype('category')

# %% [markdown]
# Looking at the modified datatypes of the columns in the dataset.

# %%
### Looking at the modified datatypes of the dataset

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    category
#  1   Model                157 non-null    category
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    category
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
#  15  Power_perf_factor    155 non-null    float64
# dtypes: category(3), float64(12), object(1)
# memory usage: 23.4+ KB

# %% [markdown]
# From the above data it is evident that there are missing values in the dataset.

# %%
# Visual representation of the missing data in the dataset
missingno.matrix(dataset)
# Out:
# <Axes: >

# %% [markdown]
# From the above dataset, we can see that there are missing values in the column - __year_resale_value, Price_in_thousands, Engine_size, Horsepower, Wheelbase, Width, Length, Curb_weight, Fuel_capacity, Fuel_efficiency, Power_perf_factor.

# %%
dataset.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# 25%       2.300000  149.500000  103.000000   68.400000  177.575000
# 50%       3.000000  177.500000  107.000000   70.550000  187.900000
# 75%       3.575000  215.000000  112.200000   73.425000  196.125000
# max       8.000000  450.000000  138.700000   79.900000  224.500000
#
#        Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor
# count   155.000000     156.000000       154.000000         155.000000
# mean      3.378026      17.951923        23.844156          77.043591
# std       0.630502       3.887921         4.282706          25.142664
# min       1.895000      10.300000        15.000000          23.276272
# 25%       2.971000      15.800000        21.000000          60.407707
# 50%       3.342000      17.200000        24.000000          72.030917
# 75%       3.799500      19.575000        26.000000          89.414878
# max       5.572000      32.000000        45.000000         188.144323

# %% [markdown]
# ## 2 Feature Analysis

# %% [markdown]
# ### Categorical variable - Manufacturer

# %%
# Value counts of the column - Manufacturer

manufacturer_count = dataset['Manufacturer'].value_counts(dropna = False)
manufacturer_count
# Out:
# Manufacturer
# Dodge         11
# Ford          11
# Mercedes-B     9
# Toyota         9
# Chevrolet      9
# Nissan         7
# Chrysler       7
# Mitsubishi     7
# Volvo          6
# Oldsmobile     6
# Lexus          6
# Mercury        6
# Pontiac        6
# Volkswagen     6
# Saturn         5
# Cadillac       5
# Honda          5
# Plymouth       4
# Acura          4
# Buick          4
# Audi           3
# Jeep           3
# Porsche        3
# Hyundai        3
# BMW            3
# Lincoln        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: count, dtype: int64

# %%
### Bar graph showing the value counts of the column - Manufacturer

plt.figure(figsize = (20, 6))
sns.barplot(manufacturer_count.values, alpha = 0.8)
plt.title('Bar graph showing the value counts of the column - Manufacturer')
plt.ylabel('Number of Occurrences', fontsize = 12)
plt.xlabel('Manufacturer', fontsize = 12)
plt.show()

# %% [markdown]
# From the above graph, we can see that the number of occurences of the car manufacturers is not uniformly distributed.

# %%
# Mean price per each Manufacturer 

mean_price_manufacturer = dataset[['Manufacturer', 'Price_in_thousands']].groupby('Manufacturer', as_index = False).mean()
print(mean_price_manufacturer)
# Out:
#    Manufacturer  Price_in_thousands
# 0         Acura           30.633333
# 1          Audi           39.980000
# 2           BMW           33.096667
# 3         Buick           26.781250
# 4      Cadillac           40.254000
# 5     Chevrolet           20.022778
# 6      Chrysler           23.430833
# 7         Dodge           24.213636
# 8          Ford           21.047273
# 9         Honda           20.277000
# 10      Hyundai           12.165667
# 11     Infiniti           29.465000
# 12       Jaguar           42.800000
# 13         Jeep           20.991667
# 14        Lexus           44.055000
# 15      Lincoln           41.690000
# 16   Mercedes-B           52.916667
# 17      Mercury           20.748333
# 18   Mitsubishi           22.167429
# 19       Nissan           22.360714
# 20   Oldsmobile           25.622833
# 21     Plymouth           22.642500
# 22      Pontiac           22.949167
# 23      Porsche           62.473333
# 24         Saab           29.610000
# 25       Saturn           14.271000
# 26       Subaru           21.395000
# 27       Toyota           21.982889
# 28   Volkswagen           17.698333
# 29        Volvo           30.933333

# %%
# Mean Price for each Manufacturer

plt.figure(figsize = (20, 6))
sns.barplot(mean_price_manufacturer['Manufacturer'])
plt.title('Mean Sales Price for each Manufacturer')
plt.ylabel('Mean Price', fontsize = 12)
plt.xlabel('Manufacturer', fontsize = 12)
plt.show()

# %% [markdown]
# ### Categorical variable - Vehicle_type

# %%
# Value counts of the column - Vehicle_type

vehicle_count = dataset['Vehicle_type'].value_counts(dropna = False)
vehicle_count
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
# Bar graph showing the value counts of the column - Vehicle_type

sns.barplot(vehicle_count.values, alpha = 0.8)
plt.title('Bar graph showing the value counts of the column - Vehicle type')
plt.ylabel('Number of Occurrences', fontsize = 12)
plt.xlabel('Vehicle type', fontsize = 12)
plt.show()

# %% [markdown]
# From the above graph, we can see that most of the values in the column are Passenger.

# %%
# Mean price per each Vehicle type

mean_price_vehicle = dataset[['Vehicle_type', 'Price_in_thousands']].groupby('Vehicle_type', as_index = False).mean()
mean_price_vehicle
# Out:
#   Vehicle_type  Price_in_thousands
# 0          Car           26.319975
# 1    Passenger           27.763200

# %%
# Mean Price for each Vehicle_type

sns.barplot(mean_price_vehicle['Price_in_thousands'], alpha = 0.8)
plt.title('Mean Sales Price for each Vehicle type')
plt.ylabel('Mean Price', fontsize = 12)
plt.xlabel('Vehicle type', fontsize = 12)
plt.show()

# %% [markdown]
# From the above graph, we can see that the mean sales price is similar for both the vehicle types.

# %% [markdown]
# ### Numerical variable - Sales_in_thousands

# %%
# Understanding the distribution of the column - Sales_in_thousands

sns.displot(dataset['Sales_in_thousands'], label = 'Skewness: %.2f'%(dataset['Sales_in_thousands'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Sales in thousands')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Sales in thousands')

# %% [markdown]
# From the above graph, we can see that the data is slightly skewed. We will remove this skewness during the Data Preprocessing phase.

# %% [markdown]
# ### Numerical variable - __year_resale_value

# %%
# Understanding the distribution of the column - __year_resale_value

sns.displot(dataset['__year_resale_value'], label = 'Skewness: %.2f'%(dataset['__year_resale_value'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - __year_resale_value')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - __year_resale_value')

# %% [markdown]
# From the above graph, we can see that the data is slightly skewed. We will remove this skewness during the Data Preprocessing phase.

# %% [markdown]
# ### Numerical variable - Price_in_thousands

# %%
### Understanding the distribution of the column - Price_in_thousands

sns.distplot(dataset['Price_in_thousands'], label = 'Skewness: %.2f'%(dataset['Price_in_thousands'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Price_in_thousands')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Price_in_thousands')

# %% [markdown]
# From the above graph, we can see that the data is slightly skewed. We will remove this skewness during the Data Preprocessing phase.

# %% [markdown]
# ### Numerical variable - Engine_size

# %%
# Understanding the distribution of the column - Engine_size

sns.distplot(dataset['Engine_size'], label = 'Skewness: %.2f'%(dataset['Engine_size'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Engine_size')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Engine_size')

# %% [markdown]
# From the above graph, we can see that the data is slightly skewed. We will remove this skewness during the Data Preprocessing phase.

# %% [markdown]
# ### Numerical variable - Horsepower

# %%
# Understanding the distribution of the column - Horsepower

sns.distplot(dataset['Horsepower'], label = 'Skewness: %.2f'%(dataset['Horsepower'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Horsepower')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Horsepower')

# %% [markdown]
# From the above graph, we can see that the data is slightly skewed. We will remove this skewness during the Data Preprocessing phase.

# %% [markdown]
# ### Numerical variable - Wheelbase

# %%
# Understanding the distribution of the column - Wheelbase

sns.distplot(dataset['Wheelbase'], label = 'Skewness: %.2f'%(dataset['Wheelbase'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Wheelbase')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Wheelbase')

# %% [markdown]
# From the above graph, we can see that the data is slightly skewed. We will remove this skewness during the Data Preprocessing phase.

# %% [markdown]
# ### Numerical variable - Width

# %%
# Understanding the distribution of the column - Width

sns.distplot(dataset['Width'], label = 'Skewness: %.2f'%(dataset['Width'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Width')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Width')

# %% [markdown]
# From the above graph, we can see that the data is normally distributed.

# %% [markdown]
# ### Numerical variable - Length

# %%
# Understanding the distribution of the column - Length

sns.distplot(dataset['Length'], label = 'Skewness: %.2f'%(dataset['Length'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Length')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Length')

# %% [markdown]
# From the above graph, we can see that the data is normally distributed.

# %% [markdown]
# ### Numerical variable - Curb_weight

# %%
### Understanding the distribution of the column - Curb_weight

sns.distplot(dataset['Curb_weight'], label = 'Skewness: %.2f'%(dataset['Curb_weight'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Curb_weight')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Curb_weight')

# %% [markdown]
# From the above graph, we can see that the data is normally distributed.

# %% [markdown]
# ### Numerical variable - Fuel_capacity

# %%
# Understanding the distribution of the column - Fuel_capacity

sns.distplot(dataset['Fuel_capacity'], label = 'Skewness: %.2f'%(dataset['Fuel_capacity'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Fuel_capacity')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Fuel_capacity')

# %% [markdown]
# From the above graph, we can see that the data is slightly skewed. We will remove this skewness during the Data Preprocessing phase.

# %% [markdown]
# ### Numerical variable - Fuel_efficiency

# %%
# Understanding the distribution of the column - Fuel_efficiency

sns.distplot(dataset['Fuel_efficiency'], label = 'Skewness: %.2f'%(dataset['Fuel_efficiency'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Fuel_efficiency')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Fuel_efficiency')

# %% [markdown]
# From the above graph, we can see that the data is normally distributed.

# %% [markdown]
# ### Numerical variable - Power_perf_factor

# %%
# Understanding the distribution of the column - Power_perf_factor

sns.distplot(dataset['Power_perf_factor'], label = 'Skewness: %.2f'%(dataset['Power_perf_factor'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Power_perf_factor')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Power_perf_factor')

# %% [markdown]
# From the above graph, we can see that the data is slightly skewed. We will remove this skewness during the Data Preprocessing phase.

# %% [markdown]
# # 4. Data Preprocessing

# %% [markdown]
# Data preprocessing is the process of getting our dataset ready for model training. In this section, we will perform the following preprocessing steps:
#
# 1. Detect and remove outliers in numerical variables
# 2. Drop and fill missing values
# 3. Feature Engineering
# 4. Data Trasformation
# 5. Feature Encoding
# 6. Feature Selection

# %% [markdown]
# ### Detect and remove outliers in numerical variables

# %% [markdown]
# It is important to address this because outliers tend to skew our data towards extremes and can cause inaccurate model predictions. I will use the Tukey method to remove these outliers.
#
# Here, we will write a function that will loop through a list of features and detect outliers in each one of those features. In each loop, a data point is deemed an outlier if it is less than the first quartile minus the outlier step or exceeds third quartile plus the outlier step. The outlier step is defined as 1.5 times the interquartile range. Once the outliers have been determined for one feature, their indices will be stored in a list before proceeding to the next feature and the process repeats until the very last feature is completed. Finally, using the list with outlier indices, we will count the frequencies of the index numbers and return them if their frequency exceeds n times.

# %%
def detect_outliers(df, n, features_list):
    outlier_indices = [] 
    for feature in features_list: 
        Q1 = np.percentile(df[feature], 25)
        Q3 = np.percentile(df[feature], 75)
        IQR = Q3 - Q1
        outlier_step = 1.5 * IQR 
        outlier_list_col = df[(df[feature] < Q1 - outlier_step) | (df[feature] > Q3 + outlier_step)].index
        outlier_indices.extend(outlier_list_col) 
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(key for key, value in outlier_indices.items() if value > n) 
    return multiple_outliers

outliers_to_drop = detect_outliers(dataset, 2, ['Sales_in_thousands', '__year_resale_value', 'Price_in_thousands', 
                                               'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length', 'Curb_weight',
                                               'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor'])
print("We will drop these {} indices: ".format(len(outliers_to_drop)), outliers_to_drop)
# Out:
# We will drop these 0 indices:  []

# %% [markdown]
# From the above cell, we can see that there are no outliers in the data.

# %% [markdown]
# ### Drop and fill missing values

# %% [markdown]
# We will first remove the records that have missing Price_in_thousands.

# %%
# Filtering the rows that has a value in the column - Price_in_thousands
modified_dataset = dataset[dataset['Price_in_thousands'].notna()]
modified_dataset
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# 1      Passenger               28.40          3.2       225.0      108.1
# 3      Passenger               42.00          3.5       210.0      114.6
# 4      Passenger               23.99          1.8       150.0      102.6
# 5      Passenger               33.95          2.8       200.0      108.7
# ..           ...                 ...          ...         ...        ...
# 152    Passenger               24.40          1.9       160.0      100.5
# 153    Passenger               27.50          2.4       168.0      104.9
# 154    Passenger               28.80          2.4       168.0      104.9
# 155    Passenger               45.50          2.3       236.0      104.9
# 156    Passenger               36.00          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0     67.3   172.4        2.639           13.2             28.0      2/2/2012
# 1     70.3   192.9        3.517           17.2             25.0      6/3/2011
# 3     71.4   196.6        3.850           18.0             22.0     3/10/2011
# 4     68.2   178.0        2.998           16.4             27.0     10/8/2011
# 5     76.1   192.0        3.561           18.5             22.0      8/9/2011
# ..     ...     ...          ...            ...              ...           ...
# 152   67.6   176.6        3.042           15.8             25.0     9/21/2011
# 153   69.3   185.9        3.208           17.9             25.0    11/24/2012
# 154   69.3   186.2        3.259           17.9             25.0     6/25/2011
# 155   71.5   185.7        3.601           18.5             23.0     4/26/2011
# 156   72.1   189.8        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# 3            91.389779
# 4            62.777639
# 5            84.565105
# ..                 ...
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655
#
# [155 rows x 16 columns]

# %%
# Looking at the missing values in the dataset
modified_dataset.isnull().sum().sort_values(ascending = False)
# Out:
# __year_resale_value    36
# Fuel_efficiency         2
# Curb_weight             1
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# Vehicle_type            0
# Price_in_thousands      0
# Engine_size             0
# Horsepower              0
# Wheelbase               0
# Width                   0
# Length                  0
# Fuel_capacity           0
# Latest_Launch           0
# Power_perf_factor       0
# dtype: int64

# %% [markdown]
# From the modified dataset, we can see that there are missing values in the columns - __year_resale_value, Fuel_efficiency, Curb_weight.

# %% [markdown]
# ### Handling missing values - __year_resale_value

# %%
# Replacing the missing values in the column - __year_resale_value using median

year_index = list(~modified_dataset['__year_resale_value'].isnull())
median_year = np.median(modified_dataset['__year_resale_value'].loc[year_index])
median_year
# Out:
# 14.01

# %%
# Replacing the missing values of the column - __year_resale_value in the dataset
modified_dataset['__year_resale_value'].fillna(median_year, inplace = True)

# %%
# Checking if there are any missing values of __year_resale_value in the dataset

modified_dataset['__year_resale_value'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Handling missing values - Fuel_efficiency

# %%
# Replacing the missing values in the column - Fuel_efficiency using median

fuel_index = list(~modified_dataset['Fuel_efficiency'].isnull())
median_fuel = np.median(modified_dataset['Fuel_efficiency'].loc[fuel_index])
median_fuel
# Out:
# 24.0

# %%
# Replacing the missing values of the column - Fuel_efficiency in the dataset

modified_dataset['Fuel_efficiency'].fillna(median_year, inplace = True)

# %%
# Checking if there are any missing values of Fuel_efficiency in the dataset

modified_dataset['Fuel_efficiency'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ###  Handling missing values - Curb_weight

# %%
# Replacing the missing values in the column - Curb_weight using median

curb_index = list(~modified_dataset['Curb_weight'].isnull())
median_curb = np.median(modified_dataset['Curb_weight'].loc[curb_index])
median_curb
# Out:
# 3.341

# %%
# Replacing the missing values of the column - Curb_weight in the dataset

modified_dataset['Curb_weight'].fillna(median_curb, inplace = True)

# %%
# Checking if there are any missing values of Curb_weight in the dataset

modified_dataset['Curb_weight'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Dropping unnecessary columns

# %% [markdown]
# Here, we will drop the columns - Model from the dataset.

# %%
# Dropping the columns - Model

modified_dataset.drop(['Model'], axis = 1, inplace = True)
modified_dataset
# Out:
#     Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0          Acura              16.919               16.360    Passenger
# 1          Acura              39.384               19.875    Passenger
# 3          Acura               8.588               29.725    Passenger
# 4           Audi              20.397               22.255    Passenger
# 5           Audi              18.780               23.555    Passenger
# ..           ...                 ...                  ...          ...
# 152        Volvo               3.545               14.010    Passenger
# 153        Volvo              15.245               14.010    Passenger
# 154        Volvo              17.531               14.010    Passenger
# 155        Volvo               3.493               14.010    Passenger
# 156        Volvo              18.969               14.010    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# 5                 33.95          2.8       200.0      108.7   76.1   192.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0          2.639           13.2             28.0      2/2/2012
# 1          3.517           17.2             25.0      6/3/2011
# 3          3.850           18.0             22.0     3/10/2011
# 4          2.998           16.4             27.0     10/8/2011
# 5          3.561           18.5             22.0      8/9/2011
# ..           ...            ...              ...           ...
# 152        3.042           15.8             25.0     9/21/2011
# 153        3.208           17.9             25.0    11/24/2012
# 154        3.259           17.9             25.0     6/25/2011
# 155        3.601           18.5             23.0     4/26/2011
# 156        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# 3            91.389779
# 4            62.777639
# 5            84.565105
# ..                 ...
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655
#
# [155 rows x 15 columns]

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# Feature engineering is arguably the most important art in machine learning. It is the process of creating new features from existing features to better represent the underlying problem to the predictive models resulting in improved model accuracy on unseen data.
#
# Here, we focus on creating new columns for:
#
# 1. NewManufacturer - using the column Manufacturer
# 2. Age - using the column Latest_Launch

# %% [markdown]
# ###  NewManufacturer - using the column Manufacturer

# %% [markdown]
# Here, we will create the NewManufacturer column such that if the mean price of a Manufacturer is less than 30 then it belongs to class 1, else class 2.

# %%
# Seperating the Manufacturers into class 1 and 2

class_1 = []
class_2 = []

for index in range(len(mean_price_manufacturer)):
    if mean_price_manufacturer.iloc[index, 1] <= 30:
        class_1.append(mean_price_manufacturer.iloc[index, 0])
    else:
        class_2.append(mean_price_manufacturer.iloc[index, 0])
        
print('Manufacturers with less than 30 mean price: ', class_1)
print('Manufacturers with more than 30 mean price: ', class_2)
# Out:
# Manufacturers with less than 30 mean price:  ['Buick', 'Chevrolet', 'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti', 'Jeep', 'Mercury', 'Mitsubishi', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen']
# Manufacturers with more than 30 mean price:  ['Acura', 'Audi', 'BMW', 'Cadillac', 'Jaguar', 'Lexus', 'Lincoln', 'Mercedes-B', 'Porsche', 'Volvo']

# %%
# Modifying the Manufacturer column in the dataset

manufacturer_data = modified_dataset['Manufacturer']
new_manufacturer_data = []

for value in manufacturer_data:
    if value in class_1:
        new_manufacturer_data.append(1)
    else:
        new_manufacturer_data.append(2)
        
modified_dataset['Manufacturer'] = new_manufacturer_data

# %%
# Looking at the modified dataset

modified_dataset
# Out:
#      Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0               2              16.919               16.360    Passenger
# 1               2              39.384               19.875    Passenger
# 3               2               8.588               29.725    Passenger
# 4               2              20.397               22.255    Passenger
# 5               2              18.780               23.555    Passenger
# ..            ...                 ...                  ...          ...
# 152             2               3.545               14.010    Passenger
# 153             2              15.245               14.010    Passenger
# 154             2              17.531               14.010    Passenger
# 155             2               3.493               14.010    Passenger
# 156             2              18.969               14.010    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# 5                 33.95          2.8       200.0      108.7   76.1   192.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0          2.639           13.2             28.0      2/2/2012
# 1          3.517           17.2             25.0      6/3/2011
# 3          3.850           18.0             22.0     3/10/2011
# 4          2.998           16.4             27.0     10/8/2011
# 5          3.561           18.5             22.0      8/9/2011
# ..           ...            ...              ...           ...
# 152        3.042           15.8             25.0     9/21/2011
# 153        3.208           17.9             25.0    11/24/2012
# 154        3.259           17.9             25.0     6/25/2011
# 155        3.601           18.5             23.0     4/26/2011
# 156        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# 3            91.389779
# 4            62.777639
# 5            84.565105
# ..                 ...
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655
#
# [155 rows x 15 columns]

# %% [markdown]
# ### Age - using the column Latest_Launch

# %% [markdown]
# Here, we will create the Age column using the formula 2022 - year value.

# %%
# Creating the Age data

age_data = []
launch_data = modified_dataset['Latest_Launch']

for value in launch_data:
    year = int(value.split('/')[-1])
    age_data.append(2022 - year)

# %%
# Adding the Age column

modified_dataset['Age'] = age_data
modified_dataset
# Out:
#      Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0               2              16.919               16.360    Passenger
# 1               2              39.384               19.875    Passenger
# 3               2               8.588               29.725    Passenger
# 4               2              20.397               22.255    Passenger
# 5               2              18.780               23.555    Passenger
# ..            ...                 ...                  ...          ...
# 152             2               3.545               14.010    Passenger
# 153             2              15.245               14.010    Passenger
# 154             2              17.531               14.010    Passenger
# 155             2               3.493               14.010    Passenger
# 156             2              18.969               14.010    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# 5                 33.95          2.8       200.0      108.7   76.1   192.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0          2.639           13.2             28.0      2/2/2012
# 1          3.517           17.2             25.0      6/3/2011
# 3          3.850           18.0             22.0     3/10/2011
# 4          2.998           16.4             27.0     10/8/2011
# 5          3.561           18.5             22.0      8/9/2011
# ..           ...            ...              ...           ...
# 152        3.042           15.8             25.0     9/21/2011
# 153        3.208           17.9             25.0    11/24/2012
# 154        3.259           17.9             25.0     6/25/2011
# 155        3.601           18.5             23.0     4/26/2011
# 156        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor  Age
# 0            58.280150   10
# 1            91.370778   11
# 3            91.389779   11
# 4            62.777639   11
# 5            84.565105   11
# ..                 ...  ...
# 152          66.498812   11
# 153          70.654495   10
# 154          71.155978   11
# 155         101.623357   11
# 156          85.735655   11
#
# [155 rows x 16 columns]

# %%
# Understanding the distribution of the column - Age

sns.distplot(modified_dataset['Age'], label = 'Skewness: %.2f'%(modified_dataset['Age'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Age')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Age')

# %% [markdown]
# From the above graph, we can see that there are only 3 main values for this column.

# %%
# Dropping the column - Latest_Launch

modified_dataset.drop(['Latest_Launch'], axis = 1, inplace = True)

# %%
# Looking at the modified dataset

modified_dataset
# Out:
#      Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0               2              16.919               16.360    Passenger
# 1               2              39.384               19.875    Passenger
# 3               2               8.588               29.725    Passenger
# 4               2              20.397               22.255    Passenger
# 5               2              18.780               23.555    Passenger
# ..            ...                 ...                  ...          ...
# 152             2               3.545               14.010    Passenger
# 153             2              15.245               14.010    Passenger
# 154             2              17.531               14.010    Passenger
# 155             2               3.493               14.010    Passenger
# 156             2              18.969               14.010    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# 5                 33.95          2.8       200.0      108.7   76.1   192.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor  Age
# 0          2.639           13.2             28.0          58.280150   10
# 1          3.517           17.2             25.0          91.370778   11
# 3          3.850           18.0             22.0          91.389779   11
# 4          2.998           16.4             27.0          62.777639   11
# 5          3.561           18.5             22.0          84.565105   11
# ..           ...            ...              ...                ...  ...
# 152        3.042           15.8             25.0          66.498812   11
# 153        3.208           17.9             25.0          70.654495   10
# 154        3.259           17.9             25.0          71.155978   11
# 155        3.601           18.5             23.0         101.623357   11
# 156        3.600           21.1             24.0          85.735655   11
#
# [155 rows x 15 columns]

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# In this section, we will remove the skewness present in the columns - Sales_in_thousands, __year_resale_value, Engine_size, Horsepower, Fuel_capacity, Power_perf_factor by using a Box-Cox transformation on the data. Then, we will normalize all the numerical columns apart from the Target using MinMax Normalization.

# %% [markdown]
# ### Box Cox transforming the column - Sales_in_thousands

# %%
# Understanding the distribution of the column - Sales_in_thousands

sns.distplot(modified_dataset['Sales_in_thousands'], label = 'Skewness: %.2f'%(modified_dataset['Sales_in_thousands'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Sales_in_thousands')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Sales_in_thousands')

# %%
# Understanding the distribution of the data Box_Cox(Sales_in_thousands)

sales_data = [1 if value == 0 else value for value in modified_dataset['Sales_in_thousands']]

modified_sales, _ = stats.boxcox(sales_data)
modified_dataset['Sales_in_thousands'] = modified_sales

sns.distplot(modified_dataset['Sales_in_thousands'], label = 'Skewness: %.2f'%(modified_dataset['Sales_in_thousands'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Sales_in_thousands')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Sales_in_thousands')

# %% [markdown]
# From the above graph, we can see that most of the skewness is removed.

# %% [markdown]
# ### Box Cox transforming the column - __year_resale_value

# %%
# Understanding the distribution of the column - __year_resale_value

sns.distplot(modified_dataset['__year_resale_value'], label = 'Skewness: %.2f'%(modified_dataset['__year_resale_value'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - __year_resale_value')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - __year_resale_value')

# %%
# Understanding the distribution of the data Box_Cox(__year_resale_value)

year_data = [1 if value == 0 else value for value in modified_dataset['__year_resale_value']]

modified_year, _ = stats.boxcox(year_data)
modified_dataset['__year_resale_value'] = modified_year

sns.distplot(modified_dataset['__year_resale_value'], label = 'Skewness: %.2f'%(modified_dataset['__year_resale_value'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - __year_resale_value')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - __year_resale_value')

# %% [markdown]
# From the above graph, we can see that most of the skewness is removed.

# %% [markdown]
# ### Box Cox transforming the column - Engine_size

# %%
# Understanding the distribution of the column - Engine_size

sns.distplot(modified_dataset['Engine_size'], label = 'Skewness: %.2f'%(modified_dataset['Engine_size'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Engine_size')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Engine_size')

# %%
# Understanding the distribution of the data Box_Cox(Engine_size)

engine_data = [1 if value == 0 else value for value in modified_dataset['Engine_size']]

modified_engine, _ = stats.boxcox(engine_data)
modified_dataset['Engine_size'] = modified_engine

sns.distplot(modified_dataset['Engine_size'], label = 'Skewness: %.2f'%(modified_dataset['Engine_size'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Engine_size')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Engine_size')

# %% [markdown]
# From the above graph, we can see that most of the skewness is removed.

# %% [markdown]
# ### Box Cox transforming the column - Horsepower

# %%
# Understanding the distribution of the column - Horsepower

sns.distplot(modified_dataset['Horsepower'], label = 'Skewness: %.2f'%(modified_dataset['Horsepower'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Horsepower')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Horsepower')

# %%
# Understanding the distribution of the data Box_Cox(Horsepower)

horsepower_data = [1 if value == 0 else value for value in modified_dataset['Horsepower']]

modified_horsepower, _ = stats.boxcox(horsepower_data)
modified_dataset['Horsepower'] = modified_horsepower

sns.distplot(modified_dataset['Horsepower'], label = 'Skewness: %.2f'%(modified_dataset['Horsepower'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Horsepower')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Horsepower')

# %% [markdown]
# From the above graph, we can see that most of the skewness is removed.

# %% [markdown]
# ### Box Cox transforming the column - Fuel_capacity

# %%
# Understanding the distribution of the column - Fuel_capacity

sns.distplot(modified_dataset['Fuel_capacity'], label = 'Skewness: %.2f'%(modified_dataset['Fuel_capacity'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Fuel_capacity')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Fuel_capacity')

# %%
# Understanding the distribution of the data Box_Cox(Fuel_capacity)

fuel_data = [1 if value == 0 else value for value in modified_dataset['Fuel_capacity']]

modified_fuel, _ = stats.boxcox(fuel_data)
modified_dataset['Fuel_capacity'] = modified_fuel

sns.distplot(modified_dataset['Fuel_capacity'], label = 'Skewness: %.2f'%(modified_dataset['Fuel_capacity'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Fuel_capacity')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Fuel_capacity')

# %% [markdown]
# From the above graph, we can see that most of the skewness is removed.

# %% [markdown]
# ### Box Cox transforming the column - Power_perf_factor

# %%
# Understanding the distribution of the column - Power_perf_factor

sns.distplot(modified_dataset['Power_perf_factor'], label = 'Skewness: %.2f'%(modified_dataset['Power_perf_factor'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Power_perf_factor')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Power_perf_factor')

# %%
# Understanding the distribution of the data Box_Cox(Power_perf_factor)

power_data = [1 if value == 0 else value for value in modified_dataset['Power_perf_factor']]

modified_power, _ = stats.boxcox(power_data)
modified_dataset['Power_perf_factor'] = modified_power

sns.distplot(modified_dataset['Power_perf_factor'], label = 'Skewness: %.2f'%(modified_dataset['Power_perf_factor'].skew()))
plt.legend(loc = 'best')
plt.title('Distribution of the column - Power_perf_factor')
# Out:
# Text(0.5, 1.0, 'Distribution of the column - Power_perf_factor')

# %% [markdown]
# From the above graph, we can see that most of the skewness is removed.

# %% [markdown]
# ## Normalizing the numerical columns

# %%
# A function to normalize numerical columns

def normalize_columns(dataframe, column):
    data = dataframe[column]
    mini = min(data)
    maxi = max(data)
    
    new_data = []
    for value in data:
        new_data.append((value - mini)/(maxi - mini))
    
    dataframe[column] = new_data

numerical_columns = ['Sales_in_thousands', '__year_resale_value', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width',
                    'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor', 'Age']
for each_column in numerical_columns:
    normalize_columns(modified_dataset, each_column)

# %%
# Looking at the sample records of the modified dataset

modified_dataset
# Out:
#      Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0               2            0.415747             0.639523    Passenger
# 1               2            0.527954             0.709378    Passenger
# 3               2            0.336772             0.829878    Passenger
# 4               2            0.439190             0.746298    Passenger
# 5               2            0.428740             0.763885    Passenger
# ..            ...                 ...                  ...          ...
# 152             2            0.246636             0.577568    Passenger
# 153             2            0.403006             0.577568    Passenger
# 154             2            0.420145             0.577568    Passenger
# 155             2            0.245244             0.577568    Passenger
# 156             2            0.429999             0.577568    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase     Width  \
# 0                 21.50     0.298740    0.402920   0.186551  0.271676
# 1                 28.40     0.578616    0.632042   0.336226  0.445087
# 3                 42.00     0.621123    0.597623   0.477223  0.508671
# 4                 23.99     0.298740    0.435156   0.216920  0.323699
# 5                 33.95     0.514740    0.573513   0.349241  0.780347
# ..                  ...          ...         ...        ...       ...
# 152               24.40     0.325560    0.465637   0.171367  0.289017
# 153               27.50     0.440196    0.488893   0.266811  0.387283
# 154               28.80     0.440196    0.488893   0.266811  0.387283
# 155               45.50     0.419462    0.656080   0.266811  0.514451
# 156               36.00     0.531588    0.575969   0.375271  0.549133
#
#        Length  Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor  \
# 0    0.306258     0.202339       0.272054         0.451436           0.424314
# 1    0.579228     0.441120       0.525932         0.354631           0.640585
# 3    0.628495     0.531683       0.566108         0.257825           0.640686
# 4    0.380826     0.299973       0.482804         0.419167           0.459679
# 5    0.567244     0.453087       0.589864         0.257825           0.602953
# ..        ...          ...            ...              ...                ...
# 152  0.362184     0.311939       0.448297         0.354631           0.487180
# 153  0.486019     0.357085       0.561236         0.354631           0.516228
# 154  0.490013     0.370955       0.561236         0.354631           0.519624
# 155  0.483356     0.463965       0.589864         0.290094           0.692564
# 156  0.537949     0.463693       0.699262         0.322362           0.609624
#
#       Age
# 0    0.00
# 1    0.25
# 3    0.25
# 4    0.25
# 5    0.25
# ..    ...
# 152  0.25
# 153  0.00
# 154  0.25
# 155  0.25
# 156  0.25
#
# [155 rows x 15 columns]

# %% [markdown]
# ## Feature Encoding

# %% [markdown]
# Feature encoding is the process of turning categorical data in a dataset into numerical data. It is essential that we perform feature encoding because most machine learning models can only interpret numerical data and not data in text form.
#
# Here, we will use One Hot Encoding for the columns - Manufacturer, Vehicle_type.

# %%
# One Hot Encoding the columns - Manufacturer, Vehicle_type of the modified dataset

encoded_dataset = pd.get_dummies(data = modified_dataset, columns = ['Manufacturer', 'Vehicle_type'])
encoded_dataset
# Out:
#      Sales_in_thousands  __year_resale_value  Price_in_thousands  Engine_size  \
# 0              0.415747             0.639523               21.50     0.298740
# 1              0.527954             0.709378               28.40     0.578616
# 3              0.336772             0.829878               42.00     0.621123
# 4              0.439190             0.746298               23.99     0.298740
# 5              0.428740             0.763885               33.95     0.514740
# ..                  ...                  ...                 ...          ...
# 152            0.246636             0.577568               24.40     0.325560
# 153            0.403006             0.577568               27.50     0.440196
# 154            0.420145             0.577568               28.80     0.440196
# 155            0.245244             0.577568               45.50     0.419462
# 156            0.429999             0.577568               36.00     0.531588
#
#      Horsepower  Wheelbase     Width    Length  Curb_weight  Fuel_capacity  \
# 0      0.402920   0.186551  0.271676  0.306258     0.202339       0.272054
# 1      0.632042   0.336226  0.445087  0.579228     0.441120       0.525932
# 3      0.597623   0.477223  0.508671  0.628495     0.531683       0.566108
# 4      0.435156   0.216920  0.323699  0.380826     0.299973       0.482804
# 5      0.573513   0.349241  0.780347  0.567244     0.453087       0.589864
# ..          ...        ...       ...       ...          ...            ...
# 152    0.465637   0.171367  0.289017  0.362184     0.311939       0.448297
# 153    0.488893   0.266811  0.387283  0.486019     0.357085       0.561236
# 154    0.488893   0.266811  0.387283  0.490013     0.370955       0.561236
# 155    0.656080   0.266811  0.514451  0.483356     0.463965       0.589864
# 156    0.575969   0.375271  0.549133  0.537949     0.463693       0.699262
#
#      Fuel_efficiency  Power_perf_factor   Age  Manufacturer_1  Manufacturer_2  \
# 0           0.451436           0.424314  0.00           False            True
# 1           0.354631           0.640585  0.25           False            True
# 3           0.257825           0.640686  0.25           False            True
# 4           0.419167           0.459679  0.25           False            True
# 5           0.257825           0.602953  0.25           False            True
# ..               ...                ...   ...             ...             ...
# 152         0.354631           0.487180  0.25           False            True
# 153         0.354631           0.516228  0.00           False            True
# 154         0.354631           0.519624  0.25           False            True
# 155         0.290094           0.692564  0.25           False            True
# 156         0.322362           0.609624  0.25           False            True
#
#      Vehicle_type_Car  Vehicle_type_Passenger
# 0               False                    True
# 1               False                    True
# 3               False                    True
# 4               False                    True
# 5               False                    True
# ..                ...                     ...
# 152             False                    True
# 153             False                    True
# 154             False                    True
# 155             False                    True
# 156             False                    True
#
# [155 rows x 17 columns]

# %%
# Create the column - Target using Price_in_thousands

target_data = encoded_dataset['Price_in_thousands']
encoded_dataset['Target'] = target_data

# Dropping the column - Price_in_thousands

encoded_dataset.drop(['Price_in_thousands'], axis = 1, inplace = True)
encoded_dataset
# Out:
#      Sales_in_thousands  __year_resale_value  Engine_size  Horsepower  \
# 0              0.415747             0.639523     0.298740    0.402920
# 1              0.527954             0.709378     0.578616    0.632042
# 3              0.336772             0.829878     0.621123    0.597623
# 4              0.439190             0.746298     0.298740    0.435156
# 5              0.428740             0.763885     0.514740    0.573513
# ..                  ...                  ...          ...         ...
# 152            0.246636             0.577568     0.325560    0.465637
# 153            0.403006             0.577568     0.440196    0.488893
# 154            0.420145             0.577568     0.440196    0.488893
# 155            0.245244             0.577568     0.419462    0.656080
# 156            0.429999             0.577568     0.531588    0.575969
#
#      Wheelbase     Width    Length  Curb_weight  Fuel_capacity  \
# 0     0.186551  0.271676  0.306258     0.202339       0.272054
# 1     0.336226  0.445087  0.579228     0.441120       0.525932
# 3     0.477223  0.508671  0.628495     0.531683       0.566108
# 4     0.216920  0.323699  0.380826     0.299973       0.482804
# 5     0.349241  0.780347  0.567244     0.453087       0.589864
# ..         ...       ...       ...          ...            ...
# 152   0.171367  0.289017  0.362184     0.311939       0.448297
# 153   0.266811  0.387283  0.486019     0.357085       0.561236
# 154   0.266811  0.387283  0.490013     0.370955       0.561236
# 155   0.266811  0.514451  0.483356     0.463965       0.589864
# 156   0.375271  0.549133  0.537949     0.463693       0.699262
#
#      Fuel_efficiency  Power_perf_factor   Age  Manufacturer_1  Manufacturer_2  \
# 0           0.451436           0.424314  0.00           False            True
# 1           0.354631           0.640585  0.25           False            True
# 3           0.257825           0.640686  0.25           False            True
# 4           0.419167           0.459679  0.25           False            True
# 5           0.257825           0.602953  0.25           False            True
# ..               ...                ...   ...             ...             ...
# 152         0.354631           0.487180  0.25           False            True
# 153         0.354631           0.516228  0.00           False            True
# 154         0.354631           0.519624  0.25           False            True
# 155         0.290094           0.692564  0.25           False            True
# 156         0.322362           0.609624  0.25           False            True
#
#      Vehicle_type_Car  Vehicle_type_Passenger  Target
# 0               False                    True   21.50
# 1               False                    True   28.40
# 3               False                    True   42.00
# 4               False                    True   23.99
# 5               False                    True   33.95
# ..                ...                     ...     ...
# 152             False                    True   24.40
# 153             False                    True   27.50
# 154             False                    True   28.80
# 155             False                    True   45.50
# 156             False                    True   36.00
#
# [155 rows x 17 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Feature selection is the process of reducing the number of input variables when developing a predictive model. It is desirable to reduce the number of input variables to both reduce the computational cost of modeling and, in some cases, to improve the performance of the model.

# %% [markdown]
# ## Plotting the correlation matrix for the numerical columns

# %%
# Creating a filter_dataset

filter_dataset = encoded_dataset[['Sales_in_thousands', '__year_resale_value', 'Engine_size', 'Horsepower', 'Wheelbase', 
                                  'Width', 'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor',
                                  'Age']]
filter_dataset
# Out:
#      Sales_in_thousands  __year_resale_value  Engine_size  Horsepower  \
# 0              0.415747             0.639523     0.298740    0.402920
# 1              0.527954             0.709378     0.578616    0.632042
# 3              0.336772             0.829878     0.621123    0.597623
# 4              0.439190             0.746298     0.298740    0.435156
# 5              0.428740             0.763885     0.514740    0.573513
# ..                  ...                  ...          ...         ...
# 152            0.246636             0.577568     0.325560    0.465637
# 153            0.403006             0.577568     0.440196    0.488893
# 154            0.420145             0.577568     0.440196    0.488893
# 155            0.245244             0.577568     0.419462    0.656080
# 156            0.429999             0.577568     0.531588    0.575969
#
#      Wheelbase     Width    Length  Curb_weight  Fuel_capacity  \
# 0     0.186551  0.271676  0.306258     0.202339       0.272054
# 1     0.336226  0.445087  0.579228     0.441120       0.525932
# 3     0.477223  0.508671  0.628495     0.531683       0.566108
# 4     0.216920  0.323699  0.380826     0.299973       0.482804
# 5     0.349241  0.780347  0.567244     0.453087       0.589864
# ..         ...       ...       ...          ...            ...
# 152   0.171367  0.289017  0.362184     0.311939       0.448297
# 153   0.266811  0.387283  0.486019     0.357085       0.561236
# 154   0.266811  0.387283  0.490013     0.370955       0.561236
# 155   0.266811  0.514451  0.483356     0.463965       0.589864
# 156   0.375271  0.549133  0.537949     0.463693       0.699262
#
#      Fuel_efficiency  Power_perf_factor   Age
# 0           0.451436           0.424314  0.00
# 1           0.354631           0.640585  0.25
# 3           0.257825           0.640686  0.25
# 4           0.419167           0.459679  0.25
# 5           0.257825           0.602953  0.25
# ..               ...                ...   ...
# 152         0.354631           0.487180  0.25
# 153         0.354631           0.516228  0.00
# 154         0.354631           0.519624  0.25
# 155         0.290094           0.692564  0.25
# 156         0.322362           0.609624  0.25
#
# [155 rows x 12 columns]

# %%
# Plotting the correlation between various columns of the filter_dataset

plt.figure(figsize = (10, 10))
heatmap = sns.heatmap(filter_dataset.corr(), vmin = -1, vmax = 1, annot = True)
heatmap.set_title('Correlation Heatmap', fontdict = {'fontsize' : 12}, pad = 12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# From the above correlation matrix, we can see that there are a few strong correlations between the data. We will use VIF to remove the multi collinearity.

# %% [markdown]
# ## Removing the columns that cause multicollinearity using VIF

# %%
# Detecting the columns that cause multicollinearity using VIF

column_names = list(filter_dataset.columns)

for name in column_names:
    if len(column_names) >= 2:
        Y = filter_dataset.loc[:, filter_dataset.columns == name]
        X = filter_dataset.loc[:, filter_dataset.columns != name]
        X = sm.add_constant(X)
        linear_model = sm.OLS(Y, X)
        results = linear_model.fit()
        r_squared = results.rsquared
        vif_value = round(1/(1 - r_squared), 2)
        print("Column: {} and VIF: {}".format(name, vif_value))
        
        if vif_value > 10:
            filter_dataset = filter_dataset.drop([name], axis = 1)
            column_names.remove(name)
# Out:
# Column: Sales_in_thousands and VIF: 1.8
# Column: __year_resale_value and VIF: 2.99
# Column: Engine_size and VIF: 7.56
# Column: Horsepower and VIF: 218.59
# Column: Width and VIF: 3.06
# Column: Length and VIF: 4.35
# Column: Curb_weight and VIF: 6.07
# Column: Fuel_capacity and VIF: 5.78
# Column: Fuel_efficiency and VIF: 4.05
# Column: Power_perf_factor and VIF: 6.59
# Column: Age and VIF: 1.04

# %% [markdown]
# From the above data, we can see that the columns - Engine_size, Horsepower, Curb_weight, Fuel_capacity, Power_perf_factor cause multicollinearity.

# %% [markdown]
# ##  Modelling

# %% [markdown]
# Scikit-learn is one of the most popular libraries for machine learning in Python and that is what we will use in the modelling part of this project.
#
# Since Car Price Prediction is a regression problem, we will need to use regression models, also known as regressors, to train on our model to make predictions. I highly recommend checking out the scikit-learn documentation for more information on the different machine learning models available in their library. I have chosen the following regression models for the job:
#
# 1. Multi Linear Regression
# 2. Lasso Regression
# 3. Ridge Regression
# 4. Support Vector Regression
# 5. Decision Tree regression
# 6. Random Forest Regression
# 7. Stacking Regression
# 8. XGBoost Regression
#
# In this section of the notebook, I will fit the models to the training set as outlined above and evaluate their Root Mean Squared Error (RMSE), R-squared at making predictions. Then, we will select the best model based on those values.

# %% [markdown]
# ### Splitting the data to Training and Test sets

# %% [markdown]
# Here, we will split the training data into X_train, X_test, Y_train, and Y_test so that they can be fed to the machine learning models that are used in the next section. Then the model with the best performance will be used to predict the result on the given test dataset.

# %%
# Splitting the dataset to the matrices X and Y

X = encoded_dataset.iloc[:, : -1].values
Y = encoded_dataset.iloc[:, -1].values

# %%
# Looking at the new training data - X

X
# Out:
# array([[0.4157471273915266, 0.6395230335644093, 0.29873983407658083, ...,
#         True, False, True],
#        [0.5279543113341153, 0.7093780604997579, 0.5786155530882126, ...,
#         True, False, True],
#        [0.33677244662272443, 0.8298778866013133, 0.6211230444881342, ...,
#         True, False, True],
#        ...,
#        [0.4201450241618963, 0.5775678199753671, 0.44019577138493465, ...,
#         True, False, True],
#        [0.24524438243422794, 0.5775678199753671, 0.4194617642529317, ...,
#         True, False, True],
#        [0.42999874397718046, 0.5775678199753671, 0.5315882084754108, ...,
#         True, False, True]], dtype=object)

# %%
# Looking at the new test data - Y

Y
# Out:
# array([21.5  , 28.4  , 42.   , 23.99 , 33.95 , 62.   , 26.99 , 33.4  ,
#        38.9  , 21.975, 25.3  , 31.965, 27.885, 39.895, 44.475, 39.665,
#        31.01 , 46.225, 13.26 , 16.535, 18.89 , 19.39 , 24.34 , 45.705,
#        13.96 ,  9.235, 18.89 , 19.84 , 24.495, 22.245, 16.48 , 28.34 ,
#        29.185, 12.64 , 19.045, 20.23 , 22.505, 69.725, 19.46 , 21.315,
#        18.575, 16.98 , 26.31 , 19.565, 12.07 , 21.56 , 17.035, 17.885,
#        12.315, 22.195, 31.93 , 21.41 , 36.135, 12.05 , 26.935, 12.885,
#        15.35 , 20.55 , 26.6  , 26.   ,  9.699, 11.799, 14.999, 29.465,
#        42.8  , 14.46 , 21.62 , 26.895, 31.505, 37.805, 46.305, 54.005,
#        60.105, 34.605, 39.08 , 43.33 , 42.66 , 13.987, 19.047, 17.357,
#        24.997, 25.45 , 31.807, 22.527, 16.24 , 16.54 , 19.035, 22.605,
#        27.56 , 22.51 , 31.75 , 49.9  , 69.7  , 82.6  , 38.9  , 41.   ,
#        41.6  , 85.5  , 35.3  , 13.499, 20.39 , 26.249, 26.399, 29.299,
#        22.799, 17.89 , 18.145, 24.15 , 18.27 , 36.229, 31.598, 25.345,
#        12.64 , 16.08 , 18.85 , 43.   , 21.61 , 19.72 , 25.31 , 21.665,
#        23.755, 25.635, 41.43 , 71.02 , 74.97 , 33.12 , 26.1  , 10.685,
#        12.535, 14.29 , 18.835, 15.01 , 22.695, 20.095, 13.108, 17.518,
#        25.545, 16.875, 11.528, 22.368, 16.888, 22.288, 51.728, 14.9  ,
#        16.7  , 21.2  , 19.99 , 17.5  , 15.9  , 23.4  , 24.4  , 27.5  ,
#        28.8  , 45.5  , 36.   ])

# %%
# Dividing the dataset into train and test in the ratio of 80 : 20

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 27, shuffle = True)

# %% [markdown]
# Now, we apply regressors using the above data.

# %% [markdown]
# ### Fit the model

# %% [markdown]
# In this section, we use various machine learning models to predict the results for our test data (X_test). We will store the model and its corresponding Root Mean Squared Error and Adjusted R-squared so that we can tabulate them later for choosing the best model.

# %%
# Dictionary to store model and its rmse
model_rmse = OrderedDict()

# %%
# Dictionary to store model and its r-squared

model_r2 = OrderedDict()

# %%
# Dictionary to store model and its mape

model_mape = OrderedDict()

# %%
# Dictionary to store model and its mae

model_mae = OrderedDict()

# %% [markdown]
# ### Applying Multi Linear Regression

# %%
# Training the Multi Linear Regression model on the Training set

linear_regressor = LinearRegression()
linear_regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results

Y_pred = linear_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)
mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Multi Linear Regression'] = rmse
model_r2['Multi Linear Regression'] = r2_value
model_mape['Multi Linear Regression'] = mape
model_mae['Multi Linear Regression'] = mae


print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))
# Out:
# Root Mean Squared Error of the model is : 4.245
# R-squared value of the model is : 0.926
#  Mean Absolute Error of the model is : 3.198
#  Mean Absolute Percentage Error  of the model is : 0.116

# %% [markdown]
# ### Applying Lasso Regression

# %%
# Training the Lasso Regression model on the Training set

lasso = Lasso()
parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-3, 1e-2, 1, 5, 10, 20, 30, 35, 40, 45, 50, 55, 100]}
lasso_regressor = GridSearchCV(lasso, parameters, scoring = 'neg_mean_squared_error', cv = 5)
lasso_regressor.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              scoring='neg_mean_squared_error')

# %%
# Finding out negative mean squared error in Lasso Regression

print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# {'alpha': 1e-15}
# -22.59284687410095

# %%
# Predicting the Test set results

Y_pred = lasso_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Lasso Regression'] = rmse
model_r2['Lasso Regression'] = r2_value

print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))

mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Lasso Regression'] = mape
model_mae['Lasso Regression'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))
# Out:
# Root Mean Squared Error of the model is : 4.347
# R-squared value of the model is : 0.922
#  Mean Absolute Error of the model is : 3.113
#  Mean Absolute Percentage Error  of the model is : 0.11

# %% [markdown]
# ### Applying Ridge Regression

# %%
# Training the Ridge Regression model on the Training set

ridge = Ridge()
parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-3, 1e-2, 1, 5, 10, 20, 30, 35, 40, 45, 50, 55, 100]}
ridge_regressor = GridSearchCV(ridge, parameters, scoring = 'neg_mean_squared_error', cv = 5)
ridge_regressor.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              scoring='neg_mean_squared_error')

# %%
# Finding out negative mean squared error in Lasso Regression

print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 1e-08}
# -22.63084910891822

# %%
# Predicting the Test set results

Y_pred = ridge_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Ridge Regression'] = rmse
model_r2['Ridge Regression'] = r2_value

print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))

mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Ridge Regression'] = mape
model_mae['Ridge Regression'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))
# Out:
# Root Mean Squared Error of the model is : 4.245
# R-squared value of the model is : 0.926
#  Mean Absolute Error of the model is : 3.198
#  Mean Absolute Percentage Error  of the model is : 0.116

# %% [markdown]
# ### Applying Support Vector Regression

# %%
# Training the Support Vector Regression model on the Training set

support_vector_regressor = SVR(kernel = 'rbf')
support_vector_regressor.fit(X_train, Y_train)
# Out:
# SVR()

# %%
# Predicting the Test set results

Y_pred = support_vector_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Support Vector Regression'] = rmse
model_r2['Support Vector Regression'] = r2_value

print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Support Vector Regression'] = mape
model_mae['Support Vector Regression'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))
# Out:
# Root Mean Squared Error of the model is : 12.113
# R-squared value of the model is : 0.394
#  Mean Absolute Error of the model is : 6.327
#  Mean Absolute Percentage Error  of the model is : 0.183

# %% [markdown]
# ### Applying Decision Tree Regression

# %%
# Training the Decision Tree Regression model on the Training set

decision_tree_regressor = DecisionTreeRegressor()
decision_tree_regressor.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Predicting the Test set results

Y_pred = decision_tree_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Decision Tree Regression'] = rmse
model_r2['Decision Tree Regression'] = r2_value

mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Decision Tree Regression'] = mape
model_mae['Decision Tree Regression'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))

print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
#  Mean Absolute Error of the model is : 4.551
#  Mean Absolute Percentage Error  of the model is : 0.168
# Root Mean Squared Error of the model is : 6.607
# R-squared value of the model is : 0.82

# %% [markdown]
# ### Applying Random Forest Regression (10 trees)

# %%
# Training the Random Forest Regression model on the Training set

random_forest_regressor = RandomForestRegressor(n_estimators = 10, random_state = 27)
random_forest_regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=27)

# %%
# Predicting the Test set results

Y_pred = random_forest_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Random Forest Regression (10 trees)'] = rmse
model_r2['Random Forest Regression (10 trees)'] = r2_value

mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Random Forest Regression (10 trees)'] = mape
model_mae['Random Forest Regression (10 trees)'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))

print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
#  Mean Absolute Error of the model is : 3.5
#  Mean Absolute Percentage Error  of the model is : 0.123
# Root Mean Squared Error of the model is : 5.957
# R-squared value of the model is : 0.853

# %% [markdown]
# ### Applying Random Forest Regression (25 trees)

# %%
# Training the Random Forest Regression model on the Training set

random_forest_regressor = RandomForestRegressor(n_estimators = 25, random_state = 27)
random_forest_regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=25, random_state=27)

# %%
# Predicting the Test set results

Y_pred = random_forest_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Random Forest Regression (25 trees)'] = rmse
model_r2['Random Forest Regression (25 trees)'] = r2_value
mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Random Forest Regression (25 trees)'] = mape
model_mae['Random Forest Regression (25 trees)'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))


print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
#  Mean Absolute Error of the model is : 3.552
#  Mean Absolute Percentage Error  of the model is : 0.12
# Root Mean Squared Error of the model is : 6.043
# R-squared value of the model is : 0.849

# %% [markdown]
# ### Applying Random Forest Regression (50 trees)

# %%
# Training the Random Forest Regression model on the Training set

random_forest_regressor = RandomForestRegressor(n_estimators = 50, random_state = 27)
random_forest_regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=27)

# %%
# Predicting the Test set results

Y_pred = random_forest_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Random Forest Regression (50 trees)'] = rmse
model_r2['Random Forest Regression (50 trees)'] = r2_value

mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Random Forest Regression (50 trees)'] = mape
model_mae['Random Forest Regression (50 trees)'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))

print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
#  Mean Absolute Error of the model is : 3.515
#  Mean Absolute Percentage Error  of the model is : 0.118
# Root Mean Squared Error of the model is : 6.112
# R-squared value of the model is : 0.846

# %% [markdown]
# ### Applying Random Forest Regression (100 trees)

# %%
# Training the Random Forest Regression model on the Training set

random_forest_regressor = RandomForestRegressor(n_estimators = 100, random_state = 27)
random_forest_regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=27)

# %%
# Predicting the Test set results

Y_pred = random_forest_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Random Forest Regression (100 trees)'] = rmse
model_r2['Random Forest Regression (100 trees)'] = r2_value

mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Random Forest Regression (100 trees)'] = mape
model_mae['Random Forest Regression (100 trees)'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))

print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
#  Mean Absolute Error of the model is : 3.419
#  Mean Absolute Percentage Error  of the model is : 0.114
# Root Mean Squared Error of the model is : 5.856
# R-squared value of the model is : 0.858

# %% [markdown]
# ### Applying Random Forest Regression (1000 trees)

# %%
# Training the Random Forest Regression model on the Training set

random_forest_regressor = RandomForestRegressor(n_estimators = 1000, random_state = 27)
random_forest_regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=27)

# %%
# Predicting the Test set results

Y_pred = random_forest_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Random Forest Regression (1000 trees)'] = rmse
model_r2['Random Forest Regression (1000 trees)'] = r2_value

mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Random Forest Regression (1000 trees)'] = mape
model_mae['Random Forest Regression (1000 trees)'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))

print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
#  Mean Absolute Error of the model is : 3.461
#  Mean Absolute Percentage Error  of the model is : 0.116
# Root Mean Squared Error of the model is : 5.988
# R-squared value of the model is : 0.852

# %% [markdown]
# ### Applying Stacking Regression

# %%
# Preparing the Stacking Regressor

### Define the base models

base_models = list()

base_models.append(('decision_tree', decision_tree_regressor))
base_models.append(('support_vector', support_vector_regressor))

### Define the meta models

meta_model = random_forest_regressor

# %%
# Training the Stacking Regression model on the Training set

stacking_regressor = StackingRegressor(estimators = base_models, final_estimator = meta_model)
stacking_regressor.fit(X_train, Y_train)
# Out:
# StackingRegressor(estimators=[('decision_tree', DecisionTreeRegressor()),
#                               ('support_vector', SVR())],
#                   final_estimator=RandomForestRegressor(n_estimators=1000,
#                                                         random_state=27))

# %%
# Predicting the Test set results

Y_pred = stacking_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['Stacking Regression'] = rmse
model_r2['Stacking Regression'] = r2_value

mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['Stacking Regression'] = mape
model_mae['Stacking Regression'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))

print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
#  Mean Absolute Error of the model is : 3.886
#  Mean Absolute Percentage Error  of the model is : 0.133
# Root Mean Squared Error of the model is : 7.777
# R-squared value of the model is : 0.75

# %% [markdown]
# ### Applying XGBoost Regression

# %%
import xgboost as xgb  

xgboost_regressor = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, seed=27)  
xgboost_regressor.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:469, in BaseEstimator._repr_mimebundle_(self, **kwargs)
#     467 output = {"text/plain": repr(self)}
#     468 if get_config()["display"] == "diagram":
# --> 469     output["text/html"] = estimator_html_repr(self)
#     470 return output
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\_estimator_html_repr.py:387, in estimator_html_repr(estimator)
#     385 else:
#     386     try:
# --> 387         check_is_fitted(estimator)
#     388         status_label = "<span>Fitted</span>"
#     389         is_fitted_css_class = "fitted"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:1751, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1748 if not hasattr(estimator, "fit"):
#    1749     raise TypeError("%s is not an estimator instance." % (estimator))
# -> 1751 tags = get_tags(estimator)
#    1753 if not tags.requires_fit and attributes is None:
#    1754     return
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\_tags.py:430, in get_tags(estimator)
#     428 for klass in reversed(type(estimator).mro()):
#     429     if "__sklearn_tags__" in vars(klass):
# --> 430         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431         class_order.append(klass)
#     432     elif "_more_tags" in vars(klass):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:613, in RegressorMixin.__sklearn_tags__(self)
#     612 def __sklearn_tags__(self):
# --> 613     tags = super().__sklearn_tags__()
#     614     tags.estimator_type = "regressor"
#     615     tags.regressor_tags = RegressorTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:463, in BaseEstimator._repr_html_inner(self)
#     458 def _repr_html_inner(self):
#     459     """This function is returned by the @property `_repr_html_` to make
#     460     `hasattr(estimator, "_repr_html_") return `True` or `False` depending
#     461     on `get_config()["display"]`.
#     462     """
# --> 463     return estimator_html_repr(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\_estimator_html_repr.py:387, in estimator_html_repr(estimator)
#     385 else:
#     386     try:
# --> 387         check_is_fitted(estimator)
#     388         status_label = "<span>Fitted</span>"
#     389         is_fitted_css_class = "fitted"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:1751, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1748 if not hasattr(estimator, "fit"):
#    1749     raise TypeError("%s is not an estimator instance." % (estimator))
# -> 1751 tags = get_tags(estimator)
#    1753 if not tags.requires_fit and attributes is None:
#    1754     return
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\_tags.py:430, in get_tags(estimator)
#     428 for klass in reversed(type(estimator).mro()):
#     429     if "__sklearn_tags__" in vars(klass):
# --> 430         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431         class_order.append(klass)
#     432     elif "_more_tags" in vars(klass):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:613, in RegressorMixin.__sklearn_tags__(self)
#     612 def __sklearn_tags__(self):
# --> 613     tags = super().__sklearn_tags__()
#     614     tags.estimator_type = "regressor"
#     615     tags.regressor_tags = RegressorTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Predicting the Test set results

Y_pred = xgboost_regressor.predict(X_test)

# %%
# Calculating RMSE and Adjusted R-squared for the model

mse = round(mean_squared_error(Y_test, Y_pred), 3)
rmse = round(sqrt(mse), 3)

r2_value = round(r2_score(Y_test, Y_pred), 3)

model_rmse['XGBoost Regression'] = rmse
model_r2['XGBoost Regression'] = r2_value

mae = round(mean_absolute_error(Y_test, Y_pred), 3) 
mape = round(mean_absolute_percentage_error(Y_test, Y_pred), 3)
model_mape['XGBoost Regression'] = mape
model_mae['XGBoost Regression'] = mae
print(' Mean Absolute Error of the model is : {}'.format(mae))
print(' Mean Absolute Percentage Error  of the model is : {}'.format(mape))


print('Root Mean Squared Error of the model is : {}'.format(rmse))
print('R-squared value of the model is : {}'.format(r2_value))
# Out:
#  Mean Absolute Error of the model is : 3.375
#  Mean Absolute Percentage Error  of the model is : 0.12
# Root Mean Squared Error of the model is : 6.094
# R-squared value of the model is : 0.847

# %% [markdown]
# ### Model evalution

# %% [markdown]
# Model evaluation is the process of using different evaluation metrics to understand a machine learning model's performance, as well as its strengths and weaknesses.

# %% [markdown]
# ### RMSE, R-squared of the models

# %% [markdown]
# Now we will tabulate all the models along with their RMSE, R-Squared. This data is stored in the model_rmse, model_r2 dictionary. We will use the tabulate package for tabulating the results.

# %%
# Looking at the model rmse dictionary

model_rmse
# Out:
# OrderedDict([('Multi Linear Regression', 4.245),
#              ('Lasso Regression', 4.347),
#              ('Ridge Regression', 4.245),
#              ('Support Vector Regression', 12.113),
#              ('Decision Tree Regression', 6.607),
#              ('Random Forest Regression (10 trees)', 5.957),
#              ('Random Forest Regression (25 trees)', 6.043),
#              ('Random Forest Regression (50 trees)', 6.112),
#              ('Random Forest Regression (100 trees)', 5.856),
#              ('Random Forest Regression (1000 trees)', 5.988),
#              ('Stacking Regression', 7.777),
#              ('XGBoost Regression', 6.094)])

# %%
# Looking at the model r-squared dictionary
model_r2
# Out:
# OrderedDict([('Multi Linear Regression', 0.926),
#              ('Lasso Regression', 0.922),
#              ('Ridge Regression', 0.926),
#              ('Support Vector Regression', 0.394),
#              ('Decision Tree Regression', 0.82),
#              ('Random Forest Regression (10 trees)', 0.853),
#              ('Random Forest Regression (25 trees)', 0.849),
#              ('Random Forest Regression (50 trees)', 0.846),
#              ('Random Forest Regression (100 trees)', 0.858),
#              ('Random Forest Regression (1000 trees)', 0.852),
#              ('Stacking Regression', 0.75),
#              ('XGBoost Regression', 0.847)])

# %%
model_mae
# Out:
# OrderedDict([('Multi Linear Regression', 3.198),
#              ('Lasso Regression', 3.113),
#              ('Ridge Regression', 3.198),
#              ('Support Vector Regression', 6.327),
#              ('Decision Tree Regression', 4.551),
#              ('Random Forest Regression (10 trees)', 3.5),
#              ('Random Forest Regression (25 trees)', 3.552),
#              ('Random Forest Regression (50 trees)', 3.515),
#              ('Random Forest Regression (100 trees)', 3.419),
#              ('Random Forest Regression (1000 trees)', 3.461),
#              ('Stacking Regression', 3.886),
#              ('XGBoost Regression', 3.375)])

# %%
model_mape
# Out:
# OrderedDict([('Multi Linear Regression', 0.116),
#              ('Lasso Regression', 0.11),
#              ('Ridge Regression', 0.116),
#              ('Support Vector Regression', 0.183),
#              ('Decision Tree Regression', 0.168),
#              ('Random Forest Regression (10 trees)', 0.123),
#              ('Random Forest Regression (25 trees)', 0.12),
#              ('Random Forest Regression (50 trees)', 0.118),
#              ('Random Forest Regression (100 trees)', 0.114),
#              ('Random Forest Regression (1000 trees)', 0.116),
#              ('Stacking Regression', 0.133),
#              ('XGBoost Regression', 0.12)])

# %%
# Tabulating the results
table = []
table.append(['S.No.', 'Model', 'Root Mean Squared Error', 'R-squared','Mean Absolute Error','Mean Absolute Percentage Error' ])
count = 1

for model in model_rmse:
    row = [count, model, model_rmse[model], model_r2[model],model_mae[model],model_mape[model]]
    table.append(row)
    count += 1
    
print(tabulate(table, headers = 'firstrow', tablefmt = 'fancy_grid'))
# Out:
# ╒═════════╤═══════════════════════════════════════╤═══════════════════════════╤═════════════╤═══════════════════════╤══════════════════════════════════╕
# │   S.No. │ Model                                 │   Root Mean Squared Error │   R-squared │   Mean Absolute Error │   Mean Absolute Percentage Error │
# ╞═════════╪═══════════════════════════════════════╪═══════════════════════════╪═════════════╪═══════════════════════╪══════════════════════════════════╡
# │       1 │ Multi Linear Regression               │                     4.245 │       0.926 │                 3.198 │                            0.116 │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │       2 │ Lasso Regression                      │                     4.347 │       0.922 │                 3.113 │                            0.11  │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │       3 │ Ridge Regression                      │                     4.245 │       0.926 │                 3.198 │                            0.116 │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │       4 │ Support Vector Regression             │                    12.113 │       0.394 │                 6.327 │                            0.183 │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │       5 │ Decision Tree Regression              │                     6.607 │       0.82  │                 4.551 │                            0.168 │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │       6 │ Random Forest Regression (10 trees)   │                     5.957 │       0.853 │                 3.5   │                            0.123 │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │       7 │ Random Forest Regression (25 trees)   │                     6.043 │       0.849 │                 3.552 │                            0.12  │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │       8 │ Random Forest Regression (50 trees)   │                     6.112 │       0.846 │                 3.515 │                            0.118 │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │       9 │ Random Forest Regression (100 trees)  │                     5.856 │       0.858 │                 3.419 │                            0.114 │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │      10 │ Random Forest Regression (1000 trees) │                     5.988 │       0.852 │                 3.461 │                            0.116 │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │      11 │ Stacking Regression                   │                     7.777 │       0.75  │                 3.886 │                            0.133 │
# ├─────────┼───────────────────────────────────────┼───────────────────────────┼─────────────┼───────────────────────┼──────────────────────────────────┤
# │      12 │ XGBoost Regression                    │                     6.094 │       0.847 │                 3.375 │                            0.12  │
# ╘═════════╧═══════════════════════════════════════╧═══════════════════════════╧═════════════╧═══════════════════════╧══════════════════════════════════╛

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
#  ## Metrics Overview
#
# - **Root Mean Squared Error (RMSE)**: Measures the average magnitude of errors between predicted and actual values. Lower values indicate better prediction accuracy.
#
# - **R-squared (R²)**: Indicates how well the model explains variability in the data. Values closer to 1 represent a better fit.
#
# - **Mean Absolute Error (MAE)**: The average absolute difference between predicted and actual values. Smaller values indicate better predictions.
#
# - **Mean Absolute Percentage Error (MAPE)**: Quantifies prediction error as a percentage of the actual values. Smaller percentages are better.

# %% [markdown]
# ## Insights by Model
#
# 1. Linear Models (Multi Linear, Ridge, Lasso)
# **Performance**: Best-performing overall with lowest RMSE and highest R².
# **Application**: Suitable for predicting car sales, explaining a large portion of variability.
#
# 2. Support Vector Regression (SVR)
# **Performance**: Worst across all metrics.
# **Application**: Avoid using this model as it struggles with capturing relationships in data.
#
# 3. Decision Tree Regression
# **Performance**: Moderate results; acceptable but less accurate than linear models and ensemble methods.
# **Application**: Should be used with caution.
#
# 4. Random Forest Regression
# **Performance**: Varies with tree count; best between 50-100 trees for a balance of accuracy and computational efficiency.
# **Application**: Use Random Forest with 50–100 trees for robust predictions.
#
# 5. Stacking Regression
# **Performance**: Mixed results; underperformed compared to single models.
# **Application**: May require improvement or better base models.
#
# 6. XGBoost Regression
# **Performance**: Solid performance; excellent choice for datasets with noise.
# **Application**: Reliable, but slightly inferior to the best linear models in this case.
#
# ## Recommendations
# 1. **Top Choice**: Multi Linear Regression or Ridge Regression for best overall metrics.
# 2. **Secondary Choice**: Random Forest Regression (50–100 Trees) for a robust option.
# 3. **Avoid**: Support Vector Regression due to poor performance.
# 4. **Backup**: XGBoost for non-linear datasets.
# 5. **Refinement**: Explore enhancing Stacking Regression with better base models and meta-models.

# %% [markdown]
# ## Hence, for this problem, we will use Linear regressor to predict the Sales Price of the Car.
